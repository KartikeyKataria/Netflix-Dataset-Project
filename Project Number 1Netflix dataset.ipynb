# %%
import pandas as pd              # Here we are importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("netflix_titles.csv")    # Here we are uploading the csv

# %%
df.info                                # This is the first step to see what is inthe csv file
# Out:
# <bound method DataFrame.info of      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# ...

# %%
df.describe                  # This has same features as info
# Out:
# <bound method NDFrame.describe of      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# ...

# %%
df.count()          # This feature is used give us some rought idea about the data whether it has duplicate or null values
# Out:
# show_id         8807
# type            8807
# title           8807
# director        6173
# cast            7982
# country         7976
# date_added      8797
# release_year    8807
# rating          8803
# duration        8804
# listed_in       8807
# description     8807
# dtype: int64

# %%
df.columns         # Here we are seeing the column names of df
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
duplicateRows = df[df.duplicated(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
       'release_year', 'rating', 'duration', 'listed_in', 'description'])]
print(duplicateRows)            #  Here what e are doing is that we are seeing wether this dataset has duplicate values in column
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
df.isna().sum()     # Here we are checking if the data set has empty values it does have we might fill or delete it
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.head()                      # Here we are seeing the top 5 of the dataset
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.hist()          # Just wanted to see the dataset in hist
# Out:
# array([[<Axes: title={'center': 'release_year'}>]], dtype=object)

# %%
df[['director','cast','country']]
# Out:
#              director                                               cast  \
# 0     Kirsten Johnson                                                NaN
# 1                 NaN  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Julien Leclercq  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                 NaN                                                NaN
# 4                 NaN  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# ...               ...                                                ...
# 8802    David Fincher  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8803              NaN                                                NaN
# 8804  Ruben Fleischer  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805     Peter Hewitt  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806      Mozez Singh  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
#             country
# 0     United States
# 1      South Africa
# 2               NaN
# ...

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df[df["title"].isin(["House of Cards"])]     # Here we are using the isin() functoin which is used to find string
# Out:
#      show_id     type           title director  \
# 1059   s1060  TV Show  House of Cards      NaN
#
#                                                    cast        country  \
# 1059  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           date_added  release_year rating   duration                listed_in  \
# 1059  April 14, 2021          2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             description
# 1059  A ruthless politician will stop at nothing to ...

# %%
df[df["title"].isin(["Zodiac"])]               # Here we are searching for a specific movie using isin functoin and also there is containstr()
# Out:
#      show_id   type   title       director  \
# 8802   s8803  Movie  Zodiac  David Fincher
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
#
#              date_added  release_year rating duration  \
# 8802  November 20, 2019          2007      R  158 min
#
#                            listed_in  \
# 8802  Cult Movies, Dramas, Thrillers
#
#                                             description
# 8802  A political cartoonist, a crime reporter and a...

# %%
df[df["director"].isin(["David Fincher"])]       # Here  we are looking for particular data in dataset using isin
# Out:
#      show_id   type                            title       director  \
# 600     s601  Movie                         The Game  David Fincher
# 1595   s1596  Movie                             MANK  David Fincher
# 7701   s7702  Movie                       Panic Room  David Fincher
# 8320   s8321  Movie  The Girl with the Dragon Tattoo  David Fincher
# 8511   s8512  Movie               The Social Network  David Fincher
# 8802   s8803  Movie                           Zodiac  David Fincher
#
#                                                    cast  \
# 600   Michael Douglas, Sean Penn, Deborah Kara Unger...
# 1595  Gary Oldman, Amanda Seyfried, Charles Dance, L...
# 7701  Jodie Foster, Forest Whitaker, Dwight Yoakam, ...
# 8320  Daniel Craig, Rooney Mara, Christopher Plummer...
# 8511  Jesse Eisenberg, Andrew Garfield, Justin Timbe...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
#
#                             country         date_added  release_year rating  \
# ...

# %%
df[df["director"].isin(["Ruben Fleischer"])]     # Here  we are looking for particular data in dataset using isin
# Out:
#      show_id   type               title         director  \
# 6012   s6013  Movie  30 Minutes or Less  Ruben Fleischer
# 8804   s8805  Movie          Zombieland  Ruben Fleischer
#
#                                                    cast        country  \
# 6012  Jesse Eisenberg, Danny McBride, Aziz Ansari, N...  United States
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
#
#             date_added  release_year rating duration  \
# 6012   January 1, 2021          2011      R   83 min
# 8804  November 1, 2019          2009      R   88 min
#
#                          listed_in  \
# 6012  Action & Adventure, Comedies
# 8804       Comedies, Horror Movies
#
#                                             description
# 6012  Two crooks planning a bank heist wind up abduc...
# 8804  Looking to survive in a world taken over by zo...

# %%
df['release_year'].value_counts()    # Here we are seeing how many movies released in which year
# Out:
# release_year
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1959       1
# 1925       1
# 1961       1
# 1947       1
# 1966       1
# Name: count, Length: 74, dtype: int64

# %%
plt.plot(df['release_year'].value_counts())    # Was trying to make Bar Graph could't make so made plt plot here

# %%
df['listed_in'].value_counts()     # Here group by didn't work here so i used value count
# Out:
# listed_in
# Dramas, International Movies                          362
# Documentaries                                         359
# Stand-Up Comedy                                       334
# Comedies, Dramas, International Movies                274
# Dramas, Independent Movies, International Movies      252
#                                                      ...
# Kids' TV, TV Action & Adventure, TV Dramas              1
# TV Comedies, TV Dramas, TV Horror                       1
# Children & Family Movies, Comedies, LGBTQ Movies        1
# Kids' TV, Spanish-Language TV Shows, Teen TV Shows      1
# Cult Movies, Dramas, Thrillers                          1
# Name: count, Length: 514, dtype: int64

# %%
plt.scatter(df['director'])

# %%
df_movie=df[df["type"]=="Movie"]        # This list will show all the movies not tv shows

# %%
df_tvshow=df[df["type"]=="TV Show"]       # This list shows all the Tv shows

# %%
df[df["type"]=="Movie"]                      # This function will show all the movies in which are india and this functin will work in two line
df[df["country"]=="India"]
# Out:
#      show_id     type                          title                 director  \
# 4         s5  TV Show                   Kota Factory                      NaN
# 24       s25    Movie                          Jeans               S. Shankar
# 39       s40  TV Show                   Chhota Bheem                      NaN
# 50       s51  TV Show                  Dharmakshetra                      NaN
# 66       s67  TV Show  Raja Rasoi Aur Anya Kahaniyan                      NaN
# ...      ...      ...                            ...                      ...
# 8773   s8774    Movie            Yanda Kartavya Aahe             Kedar Shinde
# 8775   s8776  TV Show                Yeh Meri Family                      NaN
# 8798   s8799    Movie                       Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie                          Zenda           Avadhoot Gupte
# 8806   s8807    Movie                         Zubaan              Mozez Singh
#
# ...

# %%
df[df["type"]== "Movie" ]          # Here we are seeing the movies releasing in 2000
df[df['release_year']=="2000"]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
df["director"].value_counts()   # Here is the number of director with most tv and movies
# Out:
# director
# Rajiv Chilaka                     19
# Raúl Campos, Jan Suter            18
# Marcus Raboy                      16
# Suhas Kadav                       16
# Jay Karas                         14
#                                   ..
# Raymie Muzquiz, Stu Livingston     1
# Joe Menendez                       1
# Eric Bross                         1
# Will Eisenberg                     1
# Mozez Singh                        1
# Name: count, Length: 4528, dtype: int64

# %%
df["director"].value_counts().head(10)   # Director with top 10 movies and tv shows
# Out:
# director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: count, dtype: int64

# %%
df["cast"].value_counts().head()      # Here is the cast with highest numnber of movies nadntv show
# Out:
# cast
# David Attenborough                                                                         19
# Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jigna Bhardwaj, Rajesh Kava, Mousam, Swapnil    14
# Samuel West                                                                                10
# Jeff Dunham                                                                                 7
# David Spade, London Hughes, Fortune Feimster                                                6
# Name: count, dtype: int64
